# %% [markdown]
# Make a copy of this notebook to atempt the questions and do submit it using the g-form provided by your mentor.

# %% [markdown]
# **Loading the Data:**

# %% [markdown]
# Download the data from: https://drive.google.com/drive/folders/1unxeLk-KYguHXKUNfqeKNaHviQERiG2D?usp=sharing
#
# Upload it on your google drive(Upload it to a folder) and mount your google drive. Once it's done, click on `Files` option on the left sidebar of your colab notebook. You will be able to locate your Google Drive(My Drive) & locate the train.csv file. Copy the path.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv("/content/train.csv")
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0    217.0
# 1    1-2 Year             No         33536.0                  26.0    183.0
# 2   > 2 Years            Yes         38294.0                  26.0     27.0
# 3    < 1 Year             No         28619.0                 152.0    203.0
# 4    < 1 Year             No         27496.0                 152.0     39.0
#
#    Response
# 0       1.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0

# %% [markdown]
# Q1. Find out the names of the **categorical** columns and create a list named `cat_list`.

# %%
#df.describe()
numerical_columns = df.select_dtypes(include=['number']).columns
numerical_columns
# Out:
# Index(['id', 'Age', 'Driving_License', 'Region_Code', 'Previously_Insured',
#        'Annual_Premium', 'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %% [markdown]
# Q2. Find out the names of the **Numerical** columns and create a list named cat_list.

# %%
cat_list = df.select_dtypes(include=['object','category']).columns
cat_list
# Out:
# Index(['Gender', 'Vehicle_Age', 'Vehicle_Damage'], dtype='object')

# %% [markdown]
# Q3. Find out the number of missing values for each columns:

# %%
missing_count = {}
for column in df.columns:
  missing_count[column] = df[column].isnull().sum()

missing_count
# Out:
# {'id': 0,
#  'Gender': 0,
#  'Age': 0,
#  'Driving_License': 0,
#  'Region_Code': 0,
#  'Previously_Insured': 0,
#  'Vehicle_Age': 0,
#  'Vehicle_Damage': 0,
#  'Annual_Premium': 0,
#  'Policy_Sales_Channel': 0,
#  'Vintage': 1,
#  'Response': 1}

# %% [markdown]
# Q4. What is the mean age of the Male & Female drivers?

# %%
df.groupby(by='Gender')['Age'].mean()
# Out:
# Gender
# Female    36.357612
# Male      40.902570
# Name: Age, dtype: float64

# %% [markdown]
# Q5. For each of the gender category, what is the frequency of `Vehicle_Damage` (Yes/No)
#
# (Hint: Create a crosstab)

# %%
crosstab_result = pd.crosstab(df["Gender"],df["Vehicle_Damage"])
crosstab_result
# Out:
# Vehicle_Damage     No    Yes
# Gender
# Female          33023  27621
# Male            32136  39023

# %% [markdown]
# Q6. Plot the relationship betwen `Vehicle_Damage` & `Annual_Premium`
#
# Is there any relationship between these two variables?

# %%
vdap=df.groupby('Vehicle_Damage')['Annual_Premium'].mean()
vdap.head()
# Out:
# Vehicle_Damage
# No     30334.993570
# Yes    30627.408589
# Name: Annual_Premium, dtype: float64

# %% [markdown]
# Q7. Is there any relationship between the `Age` of the driver and accidents? Visualize the relationship and comment on this.

# %%
age_death = df.crosstab('')

# %% [markdown]
# Q8. You are assigned the following task:
#
# Your objective is to predict which customers respond positively to an automobile insurance offer.
#
# This is a Classification problem where the target variable is `Response`. Is the dataset balanced?
#
# (Hint: Find the distribution of the target varible)

# %% [markdown]
# Q9. As the district traffic police comissionar, you are tasked with finding:
#
#
# *   Age category of the cars
# *   the frequency of each of these categories
#
# Create a chart to showcase it to various stakeholders to take appropiate measures on pollution control.

# %% [markdown]
# Q10. As a manager of a car-insurance company, you want to understand the current market and launch a new and exciting car-insuarnce plan. You want to target the section of people who never had an insuarnce before and set the premium of the insuarance to be the current (market) average premium. How much should be the premium of your new insurance plan?
